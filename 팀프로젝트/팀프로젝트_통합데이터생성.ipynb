# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows=1300
google=pd.read_excel('./점수_갯수_크롤링/google_수정.xlsx',encoding='utf-8')

# %%
google['구글건수']=google['건수'].apply(lambda x : float(str(x).replace('-','')))

# %%
google.to_csv('google.csv',index=False)

# %%
google=pd.read_csv('google.csv',encoding='utf-8')

# %%
google=google[['구글점수','구글건수']]

# %%
goodoc=pd.read_csv('굿닥 병원평가정보(사업장명 채움).csv',encoding='euc-kr')

# %%
goodoc['진료만족도']=goodoc['진료만족도'].apply(lambda x : np.nan if x == "error" else x)
goodoc['의료진친절도']=goodoc['의료진친절도'].apply(lambda x : np.nan if x == "error" else x)
goodoc['시설만족도']=goodoc['시설만족도'].apply(lambda x : np.nan if x == "error" else x)
goodoc['평가인원']=goodoc['평가인원'].apply(lambda x : np.nan if x == "error" else x)

# %%
goodoc=goodoc[['진료만족도','의료진친절도','시설만족도','평가인원']]

# %%
hosp=pd.read_excel('종합병원 인허가 데이터.xlsx')

# %%
hosp.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스id', '개방자치단체코드', '관리번호', '인허가일자', '영업상태구분코드',
#        '영업상태명', '상세영업상태코드', '상세영업상태명', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소',
#        '도로명전체주소', '도로명우편번호', '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명',
#        '좌표정보(x)', '좌표정보(y)', '의료기관종별명', '의료인수', '입원실수', '병상수', '총면적',
#        '진료과목내용명', '지정취소일자', '완화의료지정형태', '완화의료담당부서명', '구급차특수', '구급차일반', '총인원',
#        '구조사수', '허가병상수', '병원코드', '진료만족도', '의료진친절도', '시설만족도', '평가인원'],
#       dtype='object')

# %%
hosp=hosp[['개방서비스명','개방자치단체코드','인허가일자','도로명전체주소',
          '사업장명','의료인수','입원실수','병상수','총면적','진료과목내용명']]

# %%
hosp
# Out:
#       번호 개방서비스명  개방자치단체코드     인허가일자  \
# 0      1     병원   3570000  20181106
# 1      2     병원   3150000  20181226
# 2      3     병원   3120000  19740325
# 3      4     병원   3120000  19940622
# 4      5     병원   3060000  20110309
# 5      6     병원   3180000  19820930
# 6      7     병원   3110000  19800128
# 7      8     병원   3020000  19780223
# 8      9     병원   3000000  19790324
# 9     10     병원   3140000  19930820
# 10    11     병원   3140000  19930730
# 11    12     병원   3000000  19870424
# 12    13     병원   3000000  19810709
# 13    14     병원   3230000  19710220
# 14    15     병원   3230000  19890520
# 15    16     병원   3070000  20160128
# 16    17     병원   3160000  20000209
# 17    18     병원   3160000  19830831
# 18    19     병원   3190000  19911116
# 19    20     병원   3190000  20041201
# 20    21     병원   3170000  19850621
# 21    22     병원   3930000  20080301
# 22    23     병원   3990000  20090303
# 23    24     병원   4010000  19980409
# 24    25     병원   3740000  19830518
# ...

# %%
daum=pd.read_excel('daum.xlsx',encoding='euc-kr')

# %%
daum.columns
# Out:
# Index(['번호', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '다음 평점', '다음 평가자수'],
#       dtype='object')

# %%
daum=daum[['다음 평점','다음 평가자수']]

# %%
naver=pd.read_excel('네이버평점.xlsx',encoding='euc-kr')

# %%
naver=naver[['네이버평점','네이버건수']]

# %%
naver['네이버평점']=naver['네이버평점'].apply(lambda x : np.round(x,2))

# %%
doc=pd.read_excel('전문의1.xlsx',encoding='euc-kr')
doc
# Out:
#      종별코드   종별코드명      시도코드  시도명     시군구코드     시군구명         X좌표        Y좌표  \
# 0    11.0    종합병원  220000.0   인천  220100.0    인천강화군  126.485992  37.736048
# 1    11.0    종합병원  110000.0   서울  110003.0      강서구  126.836267  37.557263
# 2     1.0  상급종합병원  110000.0   서울  110010.0     서대문구  126.940827  37.562345
# 3    11.0    종합병원  110000.0   서울  110010.0     서대문구  126.936425  37.581332
# 4    11.0    종합병원  110000.0   서울  110019.0      중랑구  127.097831  37.613276
# 5    11.0    종합병원  110000.0   서울  110013.0     영등포구  126.922500  37.512027
# 6    11.0    종합병원  110000.0   서울  110015.0      은평구  126.919701  37.620861
# 7    11.0    종합병원  110000.0   서울  110014.0      용산구  127.004258  37.533804
# 8     1.0  상급종합병원  110000.0   서울  110016.0      종로구  126.967750  37.568408
# 9    11.0    종합병원  110000.0   서울  110020.0      양천구  126.863655  37.528484
# 10   11.0    종합병원  110000.0   서울  110020.0      양천구  126.886238  37.536286
# ...

# %%
final=pd.concat([hosp,doc,google,daum,naver,goodoc],axis=1)

# %%
final.to_excel('통합데이터.xlsx',encoding='euc-kr',index=False)
